# %% [markdown]
# ## SQLite Database Management

# %% [markdown]
# Create a database, store your interesting movie names with the names of lead actor, actress, year of release and the director name. Once you have stored the details, then use any programming language of your choice to retrieve the details.

# %% [markdown]
# #### Importing required libraries

# %%
import sqlite3 as sql
import pandas as pd

# %% [markdown]
# #### Creating new SQLite database

# %%
connection=sql.connect('Movies_Database.db')
cursor=connection.cursor()

# %%
cursor.execute("DROP TABLE IF EXISTS Movies_Database")

# %% [markdown]
# #### Creating new table - movies

# %%
table = """ CREATE TABLE Movies(
            moiveName VARCHAR(50) NOT NULL,
            actorName CHAR(25) NOT NULL,
            actressName CHAR(25),
            yearOfRelease INT NOT NULL,
            directorName CHAR(25) NOT NULL
            );"""

# %%
cursor.execute(table)

# %%
query = ''' SELECT * FROM Movies'''
df = pd.read_sql_query(query, connection)
df
# Out:
# Empty DataFrame
# Columns: [moiveName, actorName, actressName, yearOfRelease, directorName]
# Index: []

# %% [markdown]
# #### Inserting data into movies table

# %%
cursor.execute('''INSERT INTO Movies VALUES ('The Space Between Us', 'Asa Butterfield', 'Britt Robertson', '2017','Peter Chelsom')''')
cursor.execute('''INSERT INTO Movies VALUES ('Moonshot', 'Cole Sprouse', 'Lana Condor', '2022','Christopher Winterbauer')''')
cursor.execute('''INSERT INTO Movies VALUES ('Vikram', 'Kamal Hassan, Fahad Fasil, Vijay Sethupathi', '', '2022','Lokesh Kanagaraj')''')
cursor.execute('''INSERT INTO Movies VALUES ('Marvel- Black Panther','Chadwick Boseman','','2018','Ryan Coogler')''')
cursor.execute('''INSERT INTO Movies VALUES ('The Maze Runner', 'Dylan OBrien,Will Poutler,Thomas Brodie-Sangster','Patricia Clarkson', '2014','Wes Ball')''')
cursor.execute('''INSERT INTO Movies VALUES ('To All The Bright Places', 'Justice Smith', 'Elle Fanning', '2020','Brett Haley')''')
cursor.execute('''INSERT INTO Movies VALUES ('Marvel- Spider Man No Way Home', 'Tom Holland', 'Zendaya', '2021 ','Jon Watts')''')
cursor.execute('''INSERT INTO Movies VALUES ('Marvel- Shang-Chi and The Legend of The Ten Rings', 'Simu Liu', 'Awkwafina', '2021',' Destin Daniel Cretton')''')
cursor.execute('''INSERT INTO Movies VALUES ('Marvel- Captain America', 'Ryan Reynolds, Dwayne Johnson', 'Gal Gadot', '2021',' Rawson Marshall Thurber')''')
cursor.execute('''INSERT INTO Movies VALUES ('Beast', 'Vijay', 'Pooja Hegde', '2022','Nelson')''')
cursor.execute('''INSERT INTO Movies VALUES ('Hridayam', 'Pranav Mohanlal', 'Kalyani Priyadarshan,Darshana Rajendran', '2021',' Vineeth Sreenivasan')''')

# %% [markdown]
# #### Displaying the table after inserting the values

# %%
query = ''' SELECT * FROM Movies'''
df = pd.read_sql_query(query, connection)
df
# Out:
#                                             moiveName  \
# 0                                The Space Between Us
# 1                                            Moonshot
# 2                                              Vikram
# 3                               Marvel- Black Panther
# 4                                     The Maze Runner
# 5                            To All The Bright Places
# 6                      Marvel- Spider Man No Way Home
# 7   Marvel- Shang-Chi and The Legend of The Ten Rings
# 8                             Marvel- Captain America
# 9                                               Beast
# 10                                           Hridayam
#
#                                            actorName  \
# 0                                    Asa Butterfield
# 1                                       Cole Sprouse
# 2        Kamal Hassan, Fahad Fasil, Vijay Sethupathi
# 3                                   Chadwick Boseman
# 4   Dylan OBrien,Will Poutler,Thomas Brodie-Sangster
# 5                                      Justice Smith
# 6                                        Tom Holland
# 7                                           Simu Liu
# 8                      Ryan Reynolds, Dwayne Johnson
# 9                                              Vijay
# 10                                   Pranav Mohanlal
#
#                                 actressName  yearOfRelease  \
# 0                           Britt Robertson           2017
# 1                               Lana Condor           2022
# 2                                                     2022
# 3                                                     2018
# 4                         Patricia Clarkson           2014
# 5                              Elle Fanning           2020
# 6                                   Zendaya           2021
# 7                                 Awkwafina           2021
# 8                                 Gal Gadot           2021
# 9                               Pooja Hegde           2022
# 10  Kalyani Priyadarshan,Darshana Rajendran           2021
#
#                 directorName
# 0              Peter Chelsom
# 1    Christopher Winterbauer
# 2           Lokesh Kanagaraj
# 3               Ryan Coogler
# 4                   Wes Ball
# 5                Brett Haley
# 6                  Jon Watts
# 7      Destin Daniel Cretton
# 8    Rawson Marshall Thurber
# 9                     Nelson
# 10       Vineeth Sreenivasan

# %% [markdown]
# #### Query-1: Sorting the movies table by yearOfRelease

# %%
query1 = ''' SELECT * FROM Movies ORDER BY 
    yearOfRelease DESC'''
df = pd.read_sql_query(query1, connection)
df
# Out:
#                                             moiveName  \
# 0                                            Moonshot
# 1                                              Vikram
# 2                                               Beast
# 3                      Marvel- Spider Man No Way Home
# 4   Marvel- Shang-Chi and The Legend of The Ten Rings
# 5                             Marvel- Captain America
# 6                                            Hridayam
# 7                            To All The Bright Places
# 8                               Marvel- Black Panther
# 9                                The Space Between Us
# 10                                    The Maze Runner
#
#                                            actorName  \
# 0                                       Cole Sprouse
# 1        Kamal Hassan, Fahad Fasil, Vijay Sethupathi
# 2                                              Vijay
# 3                                        Tom Holland
# 4                                           Simu Liu
# 5                      Ryan Reynolds, Dwayne Johnson
# 6                                    Pranav Mohanlal
# 7                                      Justice Smith
# 8                                   Chadwick Boseman
# 9                                    Asa Butterfield
# 10  Dylan OBrien,Will Poutler,Thomas Brodie-Sangster
#
#                                 actressName  yearOfRelease  \
# 0                               Lana Condor           2022
# 1                                                     2022
# 2                               Pooja Hegde           2022
# 3                                   Zendaya           2021
# 4                                 Awkwafina           2021
# 5                                 Gal Gadot           2021
# 6   Kalyani Priyadarshan,Darshana Rajendran           2021
# 7                              Elle Fanning           2020
# 8                                                     2018
# 9                           Britt Robertson           2017
# 10                        Patricia Clarkson           2014
#
#                 directorName
# 0    Christopher Winterbauer
# 1           Lokesh Kanagaraj
# 2                     Nelson
# 3                  Jon Watts
# 4      Destin Daniel Cretton
# 5    Rawson Marshall Thurber
# 6        Vineeth Sreenivasan
# 7                Brett Haley
# 8               Ryan Coogler
# 9              Peter Chelsom
# 10                  Wes Ball

# %% [markdown]
# #### Query-2: Updating the movies table by yearOfRelease

# %%
cursor.execute('''UPDATE Movies SET yearOfRelease = 2022 WHERE directorName == 'Vineeth Sreenivasan' ''')
df = pd.read_sql_query("SELECT * FROM Movies", connection)
df
# Out:
#                                             moiveName  \
# 0                                The Space Between Us
# 1                                            Moonshot
# 2                                              Vikram
# 3                               Marvel- Black Panther
# 4                                     The Maze Runner
# 5                            To All The Bright Places
# 6                      Marvel- Spider Man No Way Home
# 7   Marvel- Shang-Chi and The Legend of The Ten Rings
# 8                             Marvel- Captain America
# 9                                               Beast
# 10                                           Hridayam
#
#                                            actorName  \
# 0                                    Asa Butterfield
# 1                                       Cole Sprouse
# 2        Kamal Hassan, Fahad Fasil, Vijay Sethupathi
# 3                                   Chadwick Boseman
# 4   Dylan OBrien,Will Poutler,Thomas Brodie-Sangster
# 5                                      Justice Smith
# 6                                        Tom Holland
# 7                                           Simu Liu
# 8                      Ryan Reynolds, Dwayne Johnson
# 9                                              Vijay
# 10                                   Pranav Mohanlal
#
#                                 actressName  yearOfRelease  \
# 0                           Britt Robertson           2017
# 1                               Lana Condor           2022
# 2                                                     2022
# 3                                                     2018
# 4                         Patricia Clarkson           2014
# 5                              Elle Fanning           2020
# 6                                   Zendaya           2021
# 7                                 Awkwafina           2021
# 8                                 Gal Gadot           2021
# 9                               Pooja Hegde           2022
# 10  Kalyani Priyadarshan,Darshana Rajendran           2021
#
#                 directorName
# 0              Peter Chelsom
# 1    Christopher Winterbauer
# 2           Lokesh Kanagaraj
# 3               Ryan Coogler
# 4                   Wes Ball
# 5                Brett Haley
# 6                  Jon Watts
# 7      Destin Daniel Cretton
# 8    Rawson Marshall Thurber
# 9                     Nelson
# 10       Vineeth Sreenivasan

# %% [markdown]
# #### Query-3: Selecting the movies which has yearOfRelease <= 2020

# %%
query3 = ''' SELECT * FROM Movies WHERE yearOfRelease <= 2020'''
df = pd.read_sql_query(query3, connection)
df
# Out:
#                   moiveName                                         actorName  \
# 0      The Space Between Us                                   Asa Butterfield
# 1     Marvel- Black Panther                                  Chadwick Boseman
# 2           The Maze Runner  Dylan OBrien,Will Poutler,Thomas Brodie-Sangster
# 3  To All The Bright Places                                     Justice Smith
#
#          actressName  yearOfRelease   directorName
# 0    Britt Robertson           2017  Peter Chelsom
# 1                              2018   Ryan Coogler
# 2  Patricia Clarkson           2014       Wes Ball
# 3       Elle Fanning           2020    Brett Haley

# %% [markdown]
# #### Query-4: Selecting the movies which has No Actor or Actress Name

# %%
query4 = ''' SELECT * FROM Movies WHERE actorName ='' OR actressName =''  '''
df = pd.read_sql_query(query4, connection)
df
# Out:
#                moiveName                                    actorName  \
# 0                 Vikram  Kamal Hassan, Fahad Fasil, Vijay Sethupathi
# 1  Marvel- Black Panther                             Chadwick Boseman
#
#   actressName  yearOfRelease      directorName
# 0                       2022  Lokesh Kanagaraj
# 1                       2018      Ryan Coogler

# %% [markdown]
# #### Query-5: Selecting the movie which was directed by Shawn Levy

# %%
query5 = ''' SELECT * FROM Movies WHERE directorName == 'Nelson' '''
df = pd.read_sql_query(query5, connection)
df
# Out:
#   moiveName actorName  actressName  yearOfRelease directorName
# 0     Beast     Vijay  Pooja Hegde           2022       Nelson

# %% [markdown]
# #### Query-6: Selecting only Marvel movies from the table

# %%
query6 = '''SELECT * FROM Movies WHERE moiveName LIKE '%Marvel%' '''
df = pd.read_sql_query(query6, connection)
df
# Out:
#                                            moiveName  \
# 0                              Marvel- Black Panther
# 1                     Marvel- Spider Man No Way Home
# 2  Marvel- Shang-Chi and The Legend of The Ten Rings
# 3                            Marvel- Captain America
#
#                        actorName actressName  yearOfRelease  \
# 0               Chadwick Boseman                       2018
# 1                    Tom Holland     Zendaya           2021
# 2                       Simu Liu   Awkwafina           2021
# 3  Ryan Reynolds, Dwayne Johnson   Gal Gadot           2021
#
#                directorName
# 0              Ryan Coogler
# 1                 Jon Watts
# 2     Destin Daniel Cretton
# 3   Rawson Marshall Thurber

# %% [markdown]
# #### Query-7: Deleting the movie  "Eternals"

# %%
cursor.execute('''DELETE FROM Movies WHERE moiveName == 'Marvel- Black Panther' ''')
df = pd.read_sql_query("SELECT * FROM Movies", connection)
df
# Out:
#                                            moiveName  \
# 0                               The Space Between Us
# 1                                           Moonshot
# 2                                             Vikram
# 3                                    The Maze Runner
# 4                           To All The Bright Places
# 5                     Marvel- Spider Man No Way Home
# 6  Marvel- Shang-Chi and The Legend of The Ten Rings
# 7                            Marvel- Captain America
# 8                                              Beast
# 9                                           Hridayam
#
#                                           actorName  \
# 0                                   Asa Butterfield
# 1                                      Cole Sprouse
# 2       Kamal Hassan, Fahad Fasil, Vijay Sethupathi
# 3  Dylan OBrien,Will Poutler,Thomas Brodie-Sangster
# 4                                     Justice Smith
# 5                                       Tom Holland
# 6                                          Simu Liu
# 7                     Ryan Reynolds, Dwayne Johnson
# 8                                             Vijay
# 9                                   Pranav Mohanlal
#
#                                actressName  yearOfRelease  \
# 0                          Britt Robertson           2017
# 1                              Lana Condor           2022
# 2                                                    2022
# 3                        Patricia Clarkson           2014
# 4                             Elle Fanning           2020
# 5                                  Zendaya           2021
# 6                                Awkwafina           2021
# 7                                Gal Gadot           2021
# 8                              Pooja Hegde           2022
# 9  Kalyani Priyadarshan,Darshana Rajendran           2021
#
#                directorName
# 0             Peter Chelsom
# 1   Christopher Winterbauer
# 2          Lokesh Kanagaraj
# 3                  Wes Ball
# 4               Brett Haley
# 5                 Jon Watts
# 6     Destin Daniel Cretton
# 7   Rawson Marshall Thurber
# 8                    Nelson
# 9       Vineeth Sreenivasan

# %% [markdown]
# #### Anantha Narayanan S V
# #### E0119008
# #### III Year, SRET
